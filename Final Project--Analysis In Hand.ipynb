# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as smf
import json

# %%
con = pd.read_csv(r"C:\Users\thegr\Downloads\video-game-sales.csv")
con.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
game = pd.read_csv(r"C:\Users\thegr\Downloads\Extracted_video_games_data.csv")
game.head()
# Out:
#    Pos  Game              Game.1 Console                    Publisher  \
# 0    1   NaN          God of War  Series  Sony Computer Entertainment
# 1    2   NaN            Warriors  Series                         KOEI
# 2    3   NaN       Devil May Cry  Series                       Capcom
# 3    4   NaN    Dynasty Warriors  Series                      Unknown
# 4    5   NaN  Grand Theft Auto V     PS3               Rockstar Games
#
#                  Developer  VGChartz Score  Critic Score  User Score  \
# 0  SIE Santa Monica Studio             NaN           NaN         NaN
# 1              Omega Force             NaN           NaN         NaN
# 2                   Capcom             NaN           NaN         NaN
# 3              Omega Force             NaN           NaN         NaN
# 4           Rockstar North             NaN           9.4         NaN
#
#   Total Shipped Total Sales NA Sales PAL Sales Japan Sales Other Sales  \
# ...

# %% [markdown]
# Going through the data that I found online, only two of them held something of value to me, and what I want to play around with. However, I noticed how large the data is in both, even if one focuses on the games, and the other focuses more on the consoles. So, I think I want to try and focus on a certain few consoles and break down the data and compare my findings to see which was the most profitable. I personally believe that it would be the Wii, as it was pretty revalutionary at the time with it's motion controls, and seeing how well the games sold that nintendo made will help prove that. Others I will look it that released at that time would be PS2, PS3, Xbox 360, etc. That way, I limit myself to a certain few and don't try and spend days on end going through data.

# %%
con.keys()
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')
